# %% [markdown]
# Deaton Analysis

# %% [markdown]
# This notebook uses the following libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Import data downloaded from github.com/swcarpentry/

# %%
gap_data = pd.read_csv("data/gapminder-FiveYearData.csv", header=0)

# %% [markdown]
# (Check)

# %%
print gap_data[0:6]
# Out:
#        country  year       pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460      Asia   36.088  739.981106
# 5  Afghanistan  1977  14880372      Asia   38.438  786.113360

# %% [markdown]
# Extract information about population

# %%
gap_data[(gap_data.year == 1952)] [["continent", "lifeExp"]]
# Out:
#      continent  lifeExp
# 0         Asia   28.801
# 12      Europe   55.230
# 24      Africa   43.077
# 36      Africa   30.015
# 48    Americas   62.485
# 60     Oceania   69.120
# 72      Europe   66.800
# 84        Asia   50.939
# 96        Asia   37.484
# 108     Europe   68.000
# 120     Africa   38.223
# 132   Americas   40.414
# 144     Europe   53.820
# 156     Africa   47.622
# 168   Americas   50.917
# 180     Europe   59.600
# 192     Africa   31.975
# 204     Africa   39.031
# 216       Asia   39.417
# 228     Africa   38.523
# 240   Americas   68.750
# 252     Africa   35.463
# 264     Africa   38.092
# 276   Americas   54.745
# 288       Asia   44.000
# 300   Americas   50.643
# 312     Africa   40.715
# 324     Africa   39.143
# 336     Africa   42.111
# 348   Americas   57.206
# ...        ...      ...
# 1344    Africa   30.331
# 1356      Asia   60.396
# 1368    Europe   64.360
# 1380    Europe   65.570
# 1392    Africa   32.978
# 1404    Africa   45.009
# ...

# %% [markdown]
# Plot my data

# %%
def pop_plot(df):
types = list(pop_data.index)
y_pos = np.arange(len(types))

plt.barh(y_pos,pop_data["pop"], align='center')
plt.yticks(y_pos, types)
plt.xlabel('Total Population')
plt.ylabel('Continent')
plt.title('World Populations in 1952')
plt.show()

# %%
def pop_year[df, year]:
    assert type(year) is int, "Argumet is not a number"
    assert year>1950, "Year too small"
    '''Function that calculates total population per contient for a year. Input-datafram, year,'''
    
subset_data = df[(df.year== year][["continent", "pop"]]
pop-data=subset_data.groupby"contient").sum().sort("pop')
return pop_data
                                                   
print pop_data
                                                    
pop_data = gap_data[gap_data.year == 1952][["continent", "pop"]].groupby("continent").sum()
# Out:
#   File "<ipython-input-29-b36dc65a91b8>", line 1
#     def pop_year[df, year]:
#                 ^
# SyntaxError: invalid syntax

# %%
print pop_data
# Out:
#                     pop
# continent
# Africa     2.376405e+08
# Americas   3.451524e+08
# Asia       1.395357e+09
# Europe     4.181208e+08
# Oceania    1.068601e+07

# %%
types=lsit(pop_data.index)
y_pos=np.arange(len(types))
plt.barth(y_p
# Out:
#   File "<ipython-input-23-690ccd549bbf>", line 3
#     plt.barth(y_p
#                  ^
# SyntaxError: invalid syntax

# %%
print gap_data.year.describe()
years=range(1952,2007,5)

print years
# Out:
# count    1704.00000
# mean     1979.50000
# std        17.26533
# min      1952.00000
# 25%      1965.75000
# 50%      1979.50000
# 75%      1993.25000
# max      2007.00000
# Name: year, dtype: float64
# [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002]

# %%
for year in years:
    pop_plot[pop_year(gap_data, year)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-03547c1f2da7> in <module>()
#       1 for year in years:
# ----> 2     pop_plot[pop_year(gap_data, year)]
#
# NameError: name 'pop_plot' is not defined
